# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("Iris.csv")
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# get the required data from the dataset
dataset.iloc[:,1:5]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
# extracted the input and output data from the dataset
x=dataset.iloc[:,1:5].values

y=dataset.iloc[:,-1].values

# we need to encode the labelled data in terms of numbers
from sklearn.preprocessing import LabelEncoder
labelencoder_y=LabelEncoder()
y=labelencoder_y.fit_transform(y)

# %%
# divide the training and test data from the dataset x and y
# x  means it has both training and testing "INPUT" data
# y means it has both training and testing "OUTPUT" data

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2)

# %%
# select the algorithm and train the model using that

from sklearn.linear_model import LogisticRegression
logmodel=LogisticRegression()
logmodel.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# predict the model output using test input
y_predic=logmodel.predict(x_test)

# %%
y_predic
# Out:
# array([0, 0, 0, 2, 2, 2, 2, 1, 0, 0, 0, 0, 1, 2, 2, 2, 2, 1, 0, 2, 0, 0,
#        0, 1, 0, 1, 0, 2, 2, 1])

# %%
y_test
# Out:
# array([0, 0, 0, 2, 2, 2, 2, 1, 0, 0, 0, 0, 1, 2, 1, 2, 1, 1, 0, 2, 0, 0,
#        0, 1, 0, 1, 0, 2, 2, 1])

# %%
# find the error metric of the model prediction
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_predic)
# Out:
# 0.06666666666666667

# %%
from matplotlib import pyplot as plt
import seaborn as sns

sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=dataset)
plt.show()

# %%
# using LinearRgresssion since we are depicting numerical width based on length
# model - 1
import seaborn as sns

iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x=iris[['sepal_length']]
y=iris[['sepal_width']]
x.head()
# Out:
#    sepal_length
# 0           5.1
# 1           4.9
# 2           4.7
# 3           4.6
# 4           5.0

# %%
y.head()
# Out:
#    sepal_width
# 0          3.5
# 1          3.0
# 2          3.2
# 3          3.1
# 4          3.6

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

#print(x_train.head())
#print(x_test.head())
#print(y_train.head())
#print(y_test.head())


from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)

y_pred=lr.predict(x_test)

from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_pred)

#print(y_pred[0:5])
# Out:
# 0.15365019641900493
